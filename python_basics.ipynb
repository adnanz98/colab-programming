# %% [markdown]
# <a href="https://colab.research.google.com/github/adnanz98/colab-programming/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## H1: Write a program to perform the subtraction, multipllication and division

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
sub = num1 - num2
multi = num1*num2
div = num1//num2
print("Subtraction of two numbers is: ", sub)
print("Multiplication of two numbers is: ", multi)
print("Division of two numbers is: ", div)
# Out:
# Enter first number: 30
# Enter second number: 6
# Subtraction of two numbers is:  24
# Multiplication of two numbers is:  180
# Division of two numbers is:  5

# %%
## H2: Write a program to declare variables for id, name, batch, and hometown, and assign values, and finally print.
id = input("Enter your ID: ")
name = input("Enter your name: ")
batch = input("Enter your batch: ")
hometown = input("Enter your hometown: ")
# Out:
# Enter your ID: SM-ML-2026-B2-040
# Enter your name: Md. Moshiuzzaman Adnan
# Enter your batch: 2nd Batch
# Enter your hometown: Dhaka

# %%
## H3: Write a program to change values of an integer variable
num1 = 525
print(num1)
num1 = 625
print(num1)
# Out:
# 525
# 625

# %%
#H4: Write a program to take two string numbers and convert them to integers using explicit type conversion.
num1= input("Enter first number: ")
num2= input("Enter second number: ")
con_num1=int(num1)
con_num2=int(num2)
print("Number 1: ",con_num1)
print("Number 2: ",con_num2)
# Out:
# Enter first number: 6
# Enter second number: 7
# Number 1:  6
# Number 2:  7

# %%
## H5: Write a program to calculate and print the average of the three numbers. Round the result to two decimal places.
n1= float(input("Enter first number: "))
n2= float(input("Enter second number: "))
n3= float(input("Enter third number: "))
avg= round((n1+n2+n3)/3,2)
print("Average", avg)
# Out:
# Enter first number: 23.455
# Enter second number: 42.5674
# Enter third number: 56.453
# Average 40.83

# %%
## H6: Create a simple calculator that performs basic arithmetic operations (addition, subtraction, multiplication, division) based on user input.

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
add = num1 + num2
sub = num1 - num2
multi = num1*num2
div = num1//num2
print("Addition of two numbers is: ", add)
print("Subtraction of two numbers is: ", sub)
print("Multiplication of two numbers is: ", multi)
print("Division of two numbers is: ", div)
# Out:
# Enter first number: 40
# Enter second number: 10
# Addition of two numbers is:  50
# Subtraction of two numbers is:  30
# Multiplication of two numbers is:  400
# Division of two numbers is:  4

# %%
## H7: Write a program that asks the user to enter a single character and determines whether it is a vowel or a consonant.

# %%
## H8: Create a program that converts temperatures between Fahrenheit and Celsius based on user input.

# %%
## H9: Write a program that asks the user to enter three numbers and determines which one is the largest.
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

if num1 > num2 and num1 > num3:
    print("Largest number is:", num1)

elif num2 > num1 and num2 > num3:
    print("Largest number is:", num2)

else:
    print("Largest number is:", num3)
# Out:
# Enter first number: 13
# Enter second number: 27
# Enter third number: 17
# Largest number is: 27
