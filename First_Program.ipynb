# %% [markdown]
# <a href="https://colab.research.google.com/github/adnanz98/colab-programming/blob/main/First_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Skill Morph Family")
# Out:
# Welcome to Skill Morph Family
